# %%
! pip install torch diffusers matplotlib transformers accelerate
# Out:
# Requirement already satisfied: torch in c:\users\admin\downloads\anaconda files\lib\site-packages (2.7.1)
# Requirement already satisfied: diffusers in c:\users\admin\downloads\anaconda files\lib\site-packages (0.34.0)
# Requirement already satisfied: matplotlib in c:\users\admin\downloads\anaconda files\lib\site-packages (3.8.4)
# Requirement already satisfied: transformers in c:\users\admin\downloads\anaconda files\lib\site-packages (4.41.2)
# Requirement already satisfied: accelerate in c:\users\admin\downloads\anaconda files\lib\site-packages (1.8.1)
# Requirement already satisfied: filelock in c:\users\admin\downloads\anaconda files\lib\site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\admin\downloads\anaconda files\lib\site-packages (from torch) (4.11.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\admin\downloads\anaconda files\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx in c:\users\admin\downloads\anaconda files\lib\site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in c:\users\admin\downloads\anaconda files\lib\site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\admin\downloads\anaconda files\lib\site-packages (from torch) (2024.3.1)
# Requirement already satisfied: importlib_metadata in c:\users\admin\downloads\anaconda files\lib\site-packages (from diffusers) (7.0.1)
# Requirement already satisfied: huggingface-hub>=0.27.0 in c:\users\admin\downloads\anaconda files\lib\site-packages (from diffusers) (0.33.2)
# Requirement already satisfied: numpy in c:\users\admin\downloads\anaconda files\lib\site-packages (from diffusers) (1.26.4)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\admin\downloads\anaconda files\lib\site-packages (from diffusers) (2024.7.24)
# Requirement already satisfied: requests in c:\users\admin\downloads\anaconda files\lib\site-packages (from diffusers) (2.32.3)
# Requirement already satisfied: safetensors>=0.3.1 in c:\users\admin\downloads\anaconda files\lib\site-packages (from diffusers) (0.5.3)
# Requirement already satisfied: Pillow in c:\users\admin\downloads\anaconda files\lib\site-packages (from diffusers) (10.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\admin\downloads\anaconda files\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\admin\downloads\anaconda files\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\admin\downloads\anaconda files\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\admin\downloads\anaconda files\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\admin\downloads\anaconda files\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\admin\downloads\anaconda files\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\admin\downloads\anaconda files\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\admin\downloads\anaconda files\lib\site-packages (from transformers) (6.0.1)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in c:\users\admin\downloads\anaconda files\lib\site-packages (from transformers) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in c:\users\admin\downloads\anaconda files\lib\site-packages (from transformers) (4.66.4)
# Requirement already satisfied: psutil in c:\users\admin\downloads\anaconda files\lib\site-packages (from accelerate) (5.9.0)
# Requirement already satisfied: six>=1.5 in c:\users\admin\downloads\anaconda files\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\admin\downloads\anaconda files\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: colorama in c:\users\admin\downloads\anaconda files\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: zipp>=0.5 in c:\users\admin\downloads\anaconda files\lib\site-packages (from importlib_metadata->diffusers) (3.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\admin\downloads\anaconda files\lib\site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\admin\downloads\anaconda files\lib\site-packages (from requests->diffusers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\admin\downloads\anaconda files\lib\site-packages (from requests->diffusers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\admin\downloads\anaconda files\lib\site-packages (from requests->diffusers) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\admin\downloads\anaconda files\lib\site-packages (from requests->diffusers) (2025.7.14)

# %%
import torch
from torch import autocast
from diffusers import StableDiffusionPipeline
import matplotlib.pyplot as plt

# %%
authorization_token = ""
modelid = "CompVis/stable-diffusion-v1-4"
device = "cuda"

# %%
pipe = StableDiffusionPipeline.from_pretrained(modelid, revision="fp16", torch_dtype=torch.float16, use_auth_token=authorization_token)
pipe.to("cpu")
# Out:
# Keyword arguments {'use_auth_token': ''} are not expected by StableDiffusionPipeline and will be ignored.
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# An error occurred while trying to fetch C:\Users\admin\.cache\huggingface\hub\models--CompVis--stable-diffusion-v1-4\snapshots\2880f2ca379f41b0226444936bb7a6766a227587\vae: Error no file named diffusion_pytorch_model.safetensors found in directory C:\Users\admin\.cache\huggingface\hub\models--CompVis--stable-diffusion-v1-4\snapshots\2880f2ca379f41b0226444936bb7a6766a227587\vae.
# Defaulting to unsafe serialization. Pass `allow_pickle=False` to raise an error instead.
# An error occurred while trying to fetch C:\Users\admin\.cache\huggingface\hub\models--CompVis--stable-diffusion-v1-4\snapshots\2880f2ca379f41b0226444936bb7a6766a227587\unet: Error no file named diffusion_pytorch_model.safetensors found in directory C:\Users\admin\.cache\huggingface\hub\models--CompVis--stable-diffusion-v1-4\snapshots\2880f2ca379f41b0226444936bb7a6766a227587\unet.
# Defaulting to unsafe serialization. Pass `allow_pickle=False` to raise an error instead.
# Pipelines loaded with `dtype=torch.float16` cannot run with `cpu` device. It is not recommended to move them to `cpu` as running them will fail. Please make sure to use an accelerator to run the pipeline in inference, due to the lack of support for`float16` operations on this device in PyTorch. Please, remove the `torch_dtype=torch.float16` argument, or use another device for inference.
# Pipelines loaded with `dtype=torch.float16` cannot run with `cpu` device. It is not recommended to move them to `cpu` as running them will fail. Please make sure to use an accelerator to run the pipeline in inference, due to the lack of support for`float16` operations on this device in PyTorch. Please, remove the `torch_dtype=torch.float16` argument, or use another device for inference.
# Pipelines loaded with `dtype=torch.float16` cannot run with `cpu` device. It is not recommended to move them to `cpu` as running them will fail. Please make sure to use an accelerator to run the pipeline in inference, due to the lack of support for`float16` operations on this device in PyTorch. Please, remove the `torch_dtype=torch.float16` argument, or use another device for inference.
# Pipelines loaded with `dtype=torch.float16` cannot run with `cpu` device. It is not recommended to move them to `cpu` as running them will fail. Please make sure to use an accelerator to run the pipeline in inference, due to the lack of support for`float16` operations on this device in PyTorch. Please, remove the `torch_dtype=torch.float16` argument, or use another device for inference.
# StableDiffusionPipeline {
#   "_class_name": "StableDiffusionPipeline",
#   "_diffusers_version": "0.34.0",
#   "_name_or_path": "CompVis/stable-diffusion-v1-4",
#   "feature_extractor": [
#     "transformers",
#     "CLIPFeatureExtractor"
#   ],
#   "image_encoder": [
#     null,
#     null
#   ],
#   "requires_safety_checker": true,
#   "safety_checker": [
#     "stable_diffusion",
#     "StableDiffusionSafetyChecker"
#   ],
#   "scheduler": [
#     "diffusers",
#     "PNDMScheduler"
#   ],
#   "text_encoder": [
#     "transformers",
#     "CLIPTextModel"
#   ],
#   "tokenizer": [
#     "transformers",
#     "CLIPTokenizer"
#   ],
#   "unet": [
#     "diffusers",
#     "UNet2DConditionModel"
#   ],
#   "vae": [
#     "diffusers",
#     "AutoencoderKL"
#   ]
# }

# %%
with autocast(device):
  textprompt = str(input("Enter your prompt: "))

  image = pipe(textprompt, guidance_scale=8.5).images[0]

  imgplot = plt.imshow(image)
# Out:
# C:\Users\admin\Downloads\Anaconda Files\Lib\site-packages\torch\amp\autocast_mode.py:266: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# Enter your prompt:  small girl playing with puppy
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
with autocast(device):
  textprompt = str(input("Enter your promt: "))

  image = pipe(textprompt, guidance_scale=8.5).images[0]

  imgplot = plt.imshow(image)

# %%
with autocast(device):
  textprompt = str(input("Enter your promt: "))

  image = pipe(textprompt, guidance_scale=8.5).images[0]

  imgplot = plt.imshow(image)
# Out:
# Enter your promt: an octopus saying hi
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
with autocast(device):
  textprompt = str(input("Enter your promt: "))

  image = pipe(textprompt, guidance_scale=8.5).images[0]

  imgplot = plt.imshow(image)
# Out:
# Enter your promt: a zoo with animals and lake
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
with autocast(device):
  textprompt = str(input("Enter your promt: "))

  image = pipe(textprompt, guidance_scale=8.5).images[0]

  imgplot = plt.imshow(image)
# Out:
# Enter your promt: a sea with all flora and fauna
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
with autocast(device):
  textprompt = str(input("Enter your promt: "))

  image = pipe(textprompt, guidance_scale=8.5).images[0]

  imgplot = plt.imshow(image)
# Out:
# Enter your promt: a puppy with it's friend puppy
#   0%|          | 0/50 [00:00<?, ?it/s]
